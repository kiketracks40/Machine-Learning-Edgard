# %% [markdown]
# <a href="https://colab.research.google.com/github/kiketracks40/Machine-Learning-Edgard/blob/master/ScatterPlot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

import numpy

x = numpy.random.normal(5.0,1.0,1000)
y = numpy.random.normal(10.0,1.0,1000)

plt.scatter(x,y)
plt.show()
